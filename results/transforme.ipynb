# %%
import pandas as pd
import numpy as np

# %%
india = pd.read_csv('data/india.txt', sep='\t', encoding='utf-8')

# %%
india = india[:200]

# %%
arr  = india.values
X = []
y = []
for val in arr : 
    val = val[0]
    feature = str(val).split(',')
    X.append(feature[:-1])
    y.append(feature[-1])

# %%
all_X = []
for i in range(len(X)):
    row = ''
    for elem in X[i][:-1]:
        row += str(elem) + ' '
    row += str(X[i][-1])
    all_X.append(row)

# %%
f = open('data/indiatest.txt', 'w')
f.write('X=[')
for row in all_X[:-1]:
    f.write(row)
    f.write('; ')
 
f.write(all_X[-1])   
f.write(']\n')

f.write('Y=[')
for row in y[:-1]:
    f.write(row)
    f.write(', ')
f.write(y[-1])
f.write(']')
f.close()

# %%
ionosphere = pd.read_csv('data/ionosphere.data', sep='\t', encoding='utf-8')

# %%
arr  = india.values
X = []
y = []
for val in arr : 
    val = val[0]
    feature = str(val).split(',')
    X.append(feature[:-1])
    y.append(feature[-1])

# %%
f = open('data/ionosphere.txt', 'w')
f.write('X=[')
for row in all_X[:-1]:
    f.write(row)
    f.write('; ')
 
f.write(all_X[-1])   
f.write(']\n')

f.write('Y=[')
for row in y[:-1]:
    f.write(row)
    f.write(', ')
f.write(y[-1])
f.write(']')
f.close()

# %%
df1 = pd.read_csv("main_results.csv"); df1
# Out:
#        Dataset  Train size  Test size  Feature count  D  Model type  Time (s)  \
# 0         iris         120         30              4  2    Univarié      15.2
# 1         iris         120         30              4  2  Multivarié       1.1
# 2         iris         120         30              4  3    Univarié      30.1
# 3         iris         120         30              4  3  Multivarié       2.5
# 4         iris         120         30              4  4    Univarié      30.2
# 5         iris         120         30              4  4  Multivarié      28.0
# 6        seeds         168         42              6  2    Univarié      30.1
# 7        seeds         168         42              6  2  Multivarié       1.8
# 8        seeds         168         42              6  3    Univarié      30.1
# 9        seeds         168         42              6  3  Multivarié      11.7
# 10       seeds         168         42              6  4    Univarié      30.2
# ...

# %%
df2 = pd.read_csv("main_merge_results.csv"); df2.head(10)
# Out:
#   Dataset   Train Size   Test Size   Features Count   D       Method    Gamma  \
# 0    iris          120          30                4   2     Univarié     0.0%
# 1    iris          120          30                4   2     Univarié    20.0%
# 2    iris          120          30                4   2     Univarié    40.0%
# 3    iris          120          30                4   2     Univarié    60.0%
# 4    iris          120          30                4   2     Univarié    80.0%
# 5    iris          120          30                4   2     Univarié   100.0%
# 6    iris          120          30                4   2   Multivarié     0.0%
# 7    iris          120          30                4   2   Multivarié    20.0%
# 8    iris          120          30                4   2   Multivarié    40.0%
# 9    iris          120          30                4   2   Multivarié    60.0%
#
#       # Clusters    Gap  Error Train/Test   Time
# 0     3 clusters   0.0%             38/12   0.0s
# ...

# %%
df3 = pd.read_csv("meanshift_results.csv"); df3.head(10)
# Out:
#       dataset_name   train_size   test_size   features_count           D  \
# iris           120           30           4                2    Univarié
# iris           120           30           4                2    Univarié
# iris           120           30           4                2    Univarié
# iris           120           30           4                2    Univarié
# iris           120           30           4                2    Univarié
# iris           120           30           4                2  Multivarié
# iris           120           30           4                2  Multivarié
# iris           120           30           4                2  Multivarié
# iris           120           30           4                2  Multivarié
# iris           120           30           4                2  Multivarié
#
#        bandwith   # clusters   Gap  Erreurs_train_test  time
# iris        0.5            4  0.0%               53/18  0.0s
# ...

# %%
df4 = pd.read_csv("DBSCAN_results.csv"); df4.head(10)
# Out:
#   Dataset  TrainSize  TestSize  FeatureCount  D Multivarié/Univarié Epsilon  \
# 0    iris        120        30             4  2            Univarié    0.0%
# 1    iris        120        30             4  2            Univarié   25.0%
# 2    iris        120        30             4  2            Univarié   50.0%
# 3    iris        120        30             4  2            Univarié   75.0%
# 4    iris        120        30             4  2            Univarié  100.0%
# 5    iris        120        30             4  2          Multivarié    0.0%
# 6    iris        120        30             4  2          Multivarié   25.0%
# 7    iris        120        30             4  2          Multivarié   50.0%
# 8    iris        120        30             4  2          Multivarié   75.0%
# 9    iris        120        30             4  2          Multivarié  100.0%
#
#    #   Gap ErreursTrain/Test  Time
# 0  3  0.0%             43/13  0.0s
# 1  3  0.0%             43/13  0.0s
# ...

# %%
df5 = pd.read_csv("agglomeration_results.csv"); df5.head(10)
# Out:
#   Dataset    Method  Train Size  Test Size  Features Count  D Linkage  \
# 0    iris  Univarié         120         30               4  2  Single
# 1    iris  Univarié         120         30               4  2  Single
# 2    iris  Univarié         120         30               4  2  Single
# 3    iris  Univarié         120         30               4  2  Single
# 4    iris  Univarié         120         30               4  2  Single
# 5    iris  Univarié         120         30               4  2  Single
# 6    iris  Univarié         120         30               4  2  Single
# 7    iris  Univarié         120         30               4  2  Single
# 8    iris  Univarié         120         30               4  2  Single
# 9    iris  Univarié         120         30               4  2  Single
#
#    # Clusters   Gap Errors Train/Test  Time
# 0           1  0.0%             82/18  0.0s
# 1           2  0.0%             38/12  0.0s
# 2           3  0.0%             38/12  0.0s
# ...
